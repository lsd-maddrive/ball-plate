# %%
import os
import argparse

import pickle
import time

import neat
# import visualize
# import reporters as r

import multiprocessing
import pathlib
import numpy as np

from objects import BallOnPlate

# %%
simulation_seconds = 10.
    
def eval_genome(genome, config):
    ballOnPlate = BallOnPlate(showGUI=False, randomInitial=False)

    net = neat.nn.FeedForwardNetwork.create(genome, config)

    global_cost = 1e10

    CONST_VALUE = 0.7
    intial_positions = [[CONST_VALUE, CONST_VALUE],
                        [-CONST_VALUE, -CONST_VALUE],
                        [-CONST_VALUE, CONST_VALUE],
                        [CONST_VALUE, -CONST_VALUE],
                        [0., 0.]]

    reference_positions = [[-CONST_VALUE, -CONST_VALUE],
                           [CONST_VALUE, CONST_VALUE],
                           [CONST_VALUE, -CONST_VALUE],
                           [-CONST_VALUE, CONST_VALUE],
                           [0., 0.]]

    for i in range(len(intial_positions)):

        envInput = [0, 0]
        result = 0
        dropDown = False

        ballOnPlate.intial_pos  = np.array(intial_positions[i])
        ref_point               = np.array(reference_positions[i])

        posOnPlate = ballOnPlate.reset()
        prevPosOnPlate = posOnPlate

        prev_err    = [0, 0]
        integr_err  = 0

        while ballOnPlate.time < simulation_seconds:
            # half of plate circle
            # if i == 4:
                # ref_point = np.array([.5*math.cos(ballOnPlate.time/2), .5*math.sin(ballOnPlate.time/2)])
            # elif i == 5:
                # ref_point = np.array([.5*math.cos(ballOnPlate.time), .5*math.sin(ballOnPlate.time)])

            # Get error
            err = ref_point - posOnPlate
            result -= (err[0] * err[0] + err[1] * err[1]) * (ballOnPlate.time + 1)

            speed = (posOnPlate - prevPosOnPlate)/BallOnPlate.D_T

            # Process control system
            netInput = np.array([err[0], err[1], 
                                 posOnPlate[0], posOnPlate[1], 
                                 envInput[0], envInput[1], 
                                 speed[0], speed[1]])
            # print(netInput)
            netOutput = net.activate(netInput)

            ### PID controller
            prop    = netOutput[0]
            diff    = netOutput[1] / BallOnPlate.D_T
            integr  = netOutput[2] * BallOnPlate.D_T
                
            integr_err += err
            d_err = err - prev_err

            envInput[0] = prop * err[1] + diff * d_err[1] + integr_err[1] * integr
            envInput[0] = -envInput[0]
            envInput[1] = prop * err[0] + diff * d_err[0] + integr_err[0] * integr

            prev_err = err
            ### PID controller

            prevPosOnPlate = posOnPlate

            envInput = np.clip(envInput, -1, 1)
            
            posOnPlate, isEnd = ballOnPlate.step(envInput)
            if isEnd:
                # Bad penalty as fall
                dropDown = True
                break
            # sleep(ballOnPlate.dt)

        DROP_PENALTY_VALUE = 1e4 

        if dropDown:
            current_cost = ballOnPlate.time * (DROP_PENALTY_VALUE/(2*simulation_seconds)) + result - DROP_PENALTY_VALUE
        else:
            current_cost = ballOnPlate.time * (DROP_PENALTY_VALUE/(2*simulation_seconds)) + result

#         cost += current_cost / float(len(intial_positions))
        global_cost = min(current_cost, global_cost)

    ballOnPlate.close()
    return global_cost / 100
        
def eval_genomes(genomes, config):

    for genome_id, genome in genomes:
        genome.fitness = eval_genome(genome, config)

# %%
populationCount     = 1000
numCores            = multiprocessing.cpu_count()
print('Processing {} cores'.format(numCores))

checkpointDir       = 'checkpoints_ff'
winnerFname         = 'winner_ff'
pictureDir          = 'pictures_ff'
configFname         = 'feedforward.cfg'
logFname            = 'log_ff.txt'

checkpointPrefix    = checkpointDir + '/chk_'

if not os.path.exists(checkpointDir):
    os.makedirs(checkpointDir)

# if not os.path.exists(pictureDir):
#     os.makedirs(pictureDir)

    
# if restoreCheckpoint is None:
local_dir = str(pathlib.Path().absolute())
config_path = os.path.join(local_dir, configFname)
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

pop = neat.Population(config)
# else:
#     pop = neat.Checkpointer.restore_checkpoint(restoreCheckpoint)

stats = neat.StatisticsReporter()
pop.add_reporter(stats)
pop.add_reporter(neat.StdOutReporter(True))
# pop.add_reporter(r.FileReporter(logFname, True))
pop.add_reporter(neat.Checkpointer(generation_interval=100, filename_prefix=checkpointPrefix))

# if render_flag:
# winner = pop.run(eval_genomes)
# else:
pe = neat.ParallelEvaluator(numCores, eval_genome)
winner = pop.run(pe.evaluate, n=populationCount)

# Save the winner.
with open(winnerFname, 'wb') as f:
    pickle.dump(winner, f)

# visualize.plot_stats(stats, view=False, ylog=True, filename=pictureDir+'/fitness.svg')
# visualize.plot_species(stats, view=False, filename=pictureDir+'/speciation.svg')

# node_names = {-1: 'ext', -2: 'eyt', -3: 'sf', -4: 'sl', -5: 'sr', -6: 'sb', 0: 'ux', 1: 'uy'}
# visualize.draw_net(config, winner, False, node_names=node_names,
                   # filename='pictures_ff/Digraph.gv')
# visualize.draw_net(config, winner, view=False, node_names=node_names,
                   # filename="pictures_ff/winner-feedforward.gv")
# visualize.draw_net(config, winner, view=False, node_names=node_names,
                   # filename="pictures_ff/winner-feedforward-enabled.gv", show_disabled=False)
#visualize.draw_net(config, winner, view=False, node_names=node_names,
#                   filename="winner-feedforward-enabled-pruned.gv", show_disabled=False, prune_unused=True)
# Out:
# Processing 8 cores
#
#  ****** Running generation 0 ******
#
# Population's average fitness: -141.50862 stdev: 40.55164
# Best fitness: -97.27813 - size: (3, 24) - species 1 - id 38
# Average adjusted fitness: 0.701
# Mean genetic distance 1.297, standard deviation 0.233
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50    -97.3    0.701     0
# Total extinctions: 0
# Generation time: 5.148 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -129.53536 stdev: 40.71184
# Best fitness: -97.27813 - size: (3, 24) - species 1 - id 38
# Average adjusted fitness: 0.812
# Mean genetic distance 1.412, standard deviation 0.368
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    34    -97.3    0.812     1
#      2    0    16       --       --     0
# Total extinctions: 0
# Generation time: 3.936 sec (4.542 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -134.22756 stdev: 36.59998
# Best fitness: -97.27813 - size: (3, 24) - species 1 - id 38
# Average adjusted fitness: 0.736
# Mean genetic distance 1.653, standard deviation 0.424
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    31    -97.3    0.770     2
#      2    1    19    -97.5    0.702     0
# Total extinctions: 0
# Generation time: 4.608 sec (4.564 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -113.80851 stdev: 29.12840
# Best fitness: -97.26893 - size: (3, 21) - species 1 - id 187
# Average adjusted fitness: 0.787
# Mean genetic distance 1.683, standard deviation 0.476
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    28    -97.3    0.879     0
#      2    2    22    -97.5    0.695     1
# Total extinctions: 0
# Generation time: 3.203 sec (4.224 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -106.12964 stdev: 22.21732
# Best fitness: -97.26893 - size: (3, 21) - species 1 - id 187
# Average adjusted fitness: 0.911
# Mean genetic distance 1.742, standard deviation 0.429
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    28    -97.3    0.928     1
#      2    3    22    -97.4    0.895     0
# Total extinctions: 0
# Generation time: 3.078 sec (3.995 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -101.45708 stdev: 13.22157
# Best fitness: -97.02421 - size: (3, 21) - species 2 - id 245
# Average adjusted fitness: 0.930
# Mean genetic distance 1.713, standard deviation 0.470
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    30    -97.2    0.952     0
#      2    4    20    -97.0    0.908     0
# Total extinctions: 0
# Generation time: 2.868 sec (3.807 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -106.60278 stdev: 20.30341
# Best fitness: -97.02421 - size: (3, 21) - species 2 - id 245
# Average adjusted fitness: 0.891
# Mean genetic distance 1.793, standard deviation 0.616
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    28    -97.2    0.892     0
#      2    5    22    -97.0    0.889     1
# Total extinctions: 0
# Generation time: 3.116 sec (3.708 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -107.08321 stdev: 25.69110
# Best fitness: -96.86582 - size: (4, 18) - species 1 - id 353
# Average adjusted fitness: 0.902
# Mean genetic distance 1.916, standard deviation 0.626
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    25    -96.9    0.899     0
#      2    6    25    -96.9    0.904     0
# Total extinctions: 0
# Generation time: 3.323 sec (3.660 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -107.14085 stdev: 23.96651
# Best fitness: -96.40782 - size: (5, 20) - species 1 - id 419
# Average adjusted fitness: 0.884
# Mean genetic distance 1.915, standard deviation 0.665
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    19    -96.4    0.847     0
#      2    7    26    -96.9    0.921     1
#      3    0     5       --       --     0
# Total extinctions: 0
# Generation time: 3.298 sec (3.620 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -114.90413 stdev: 31.78673
# Best fitness: -96.40782 - size: (5, 20) - species 1 - id 419
# Average adjusted fitness: 0.848
# Mean genetic distance 1.964, standard deviation 0.642
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    13    -96.4    0.808     1
#      2    8    21    -96.7    0.773     0
#      3    1    16    -96.9    0.965     0
# Total extinctions: 0
# Generation time: 4.044 sec (3.662 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -119.73301 stdev: 37.32914
# Best fitness: -96.40782 - size: (5, 20) - species 1 - id 419
# Average adjusted fitness: 0.829
# Mean genetic distance 2.121, standard deviation 0.662
# Population of 50 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    15    -96.4    0.816     2
#      2    9    17    -96.7    0.749     1
#      3    2    17    -96.6    0.922     0
#      4    0     1       --       --     0
# Total extinctions: 0
# Generation time: 4.453 sec (3.593 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -102.86957 stdev: 19.14639
# Best fitness: -96.11701 - size: (4, 16) - species 3 - id 532
# Average adjusted fitness: 0.888
# Mean genetic distance 2.180, standard deviation 0.659
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    14    -96.4    0.974     3
#      2   10    15    -96.7    0.918     2
#      3    3    13    -96.1    0.925     0
#      4    1     6   -123.0    0.735     0
#      5    0     2       --       --     0
# Total extinctions: 0
# Generation time: 3.332 sec (3.532 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -118.89245 stdev: 32.65107
# Best fitness: -95.94670 - size: (5, 21) - species 1 - id 576
# Average adjusted fitness: 0.700
# Mean genetic distance 2.212, standard deviation 0.671
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    12    -95.9    0.763     0
#      2   11    12    -96.7    0.810     3
#      3    4    13    -96.1    0.936     1
#      4    2     5   -123.0    0.241     1
#      5    1     8    -97.4    0.751     0
# Total extinctions: 0
# Generation time: 3.843 sec (3.456 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -116.67603 stdev: 32.86382
# Best fitness: -95.94670 - size: (5, 21) - species 1 - id 576
# Average adjusted fitness: 0.747
# Mean genetic distance 2.201, standard deviation 0.731
# Population of 49 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    11    -95.9    0.849     1
#      2   12    10    -96.7    0.889     4
#      3    5    12    -96.1    0.845     2
#      4    3     7   -123.0    0.412     2
#      5    2     9    -97.3    0.739     0
# Total extinctions: 0
# Generation time: 4.542 sec (3.590 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -115.07491 stdev: 30.91189
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.823
# Mean genetic distance 2.220, standard deviation 0.751
# Population of 50 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    12    -95.4    0.968     0
#      2   13     9    -96.7    0.785     5
#      3    6    11    -96.1    0.943     3
#      4    4     8   -123.0    0.620     3
#      5    3    10    -97.3    0.797     0
# Total extinctions: 0
# Generation time: 3.567 sec (3.639 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -114.99731 stdev: 31.28508
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.776
# Mean genetic distance 2.255, standard deviation 0.744
# Population of 48 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    11    -95.4    0.902     1
#      2   14    10    -96.7    0.911     6
#      3    7    10    -96.1    0.754     4
#      4    5     6   -123.0    0.335     4
#      5    4    11    -97.3    0.977     0
# Total extinctions: 0
# Generation time: 4.361 sec (3.788 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -118.10870 stdev: 34.40730
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.817
# Mean genetic distance 2.240, standard deviation 0.724
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    10    -95.4    0.777     2
#      2   15    11    -96.7    0.938     7
#      3    8    12    -95.9    0.846     0
#      4    6     7   -123.0    0.591     5
#      5    5    11    -96.9    0.935     0
# Total extinctions: 0
# Generation time: 4.291 sec (3.905 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -118.61832 stdev: 34.93755
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.735
# Mean genetic distance 2.263, standard deviation 0.741
# Population of 51 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     9    -95.4    0.540     3
#      2   16    12    -96.7    0.951     8
#      3    9    11    -95.9    0.925     1
#      4    7     6   -123.0    0.368     0
#      5    6    13    -96.9    0.890     0
# Total extinctions: 0
# Generation time: 4.684 sec (4.042 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -115.57960 stdev: 32.07407
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.742
# Mean genetic distance 2.178, standard deviation 0.738
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     7    -95.4    0.661     4
#      2   17    11    -96.7    0.780     9
#      3   10    12    -95.9    0.847     2
#      4    8     5   -123.0    0.442     1
#      5    7    14    -96.3    0.979     0
#      6    0     1       --       --     0
# Total extinctions: 0
# Generation time: 4.497 sec (4.161 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -120.91688 stdev: 40.47239
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.757
# Mean genetic distance 2.280, standard deviation 0.692
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     8    -95.4    0.719     5
#      2   18    11    -96.7    0.887    10
#      3   11    11    -95.9    0.972     3
#      4    9     6   -123.0    0.637     2
#      5    8    11    -96.3    0.881     1
#      6    1     3   -188.0    0.450     0
# Total extinctions: 0
# Generation time: 4.106 sec (4.168 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -128.09292 stdev: 38.12915
# Best fitness: -95.36841 - size: (6, 21) - species 1 - id 672
# Average adjusted fitness: 0.599
# Mean genetic distance 2.248, standard deviation 0.630
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     7    -95.4    0.500     6
#      2   19    12    -96.6    0.808     0
#      3   12    10    -95.9    0.770     4
#      4   10     7   -122.6    0.450     0
#      5    9    12    -96.1    0.909     0
#      6    2     2   -180.4    0.159     0
# Total extinctions: 0
# Generation time: 4.837 sec (4.206 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -120.55023 stdev: 35.63310
# Best fitness: -94.55246 - size: (6, 20) - species 1 - id 953
# Average adjusted fitness: 0.666
# Mean genetic distance 2.214, standard deviation 0.608
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     9    -94.6    0.806     0
#      2   20    11    -96.6    0.776     1
#      3   13     9    -95.9    0.785     5
#      4   11     6   -105.2    0.472     0
#      5   10    13    -96.1    0.964     1
#      6    3     3   -180.4    0.192     1
# Total extinctions: 0
# Generation time: 4.901 sec (4.363 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -115.27895 stdev: 30.91260
# Best fitness: -94.55246 - size: (6, 20) - species 1 - id 953
# Average adjusted fitness: 0.695
# Mean genetic distance 2.108, standard deviation 0.623
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     8    -94.6    0.636     1
#      2   21    10    -96.6    0.874     2
#      3   14    10    -95.9    0.844     6
#      4   12     8    -97.3    0.781     0
#      5   11    12    -96.1    0.946     2
#      6    4     2   -180.4    0.092     2
# Total extinctions: 0
# Generation time: 4.058 sec (4.384 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -119.58413 stdev: 33.72900
# Best fitness: -94.55246 - size: (6, 20) - species 1 - id 953
# Average adjusted fitness: 0.642
# Mean genetic distance 2.155, standard deviation 0.637
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     9    -94.6    0.673     2
#      2   22     9    -96.5    0.615     0
#      3   15    10    -95.9    0.948     7
#      4   13     9    -97.3    0.748     1
#      5   12    12    -96.1    0.799     3
#      6    5     2   -180.4    0.067     3
# Total extinctions: 0
# Generation time: 4.290 sec (4.359 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -116.58025 stdev: 35.12309
# Best fitness: -94.55246 - size: (6, 20) - species 1 - id 953
# Average adjusted fitness: 0.755
# Mean genetic distance 2.131, standard deviation 0.694
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     8    -94.6    0.645     3
#      2   23    10    -96.5    0.893     1
#      3   16     9    -95.9    0.889     8
#      4   14    10    -97.3    0.839     0
#      5   13    11    -96.1    0.946     4
#      6    6     3   -180.4    0.316     4
# Total extinctions: 0
# Generation time: 4.473 sec (4.450 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -117.55886 stdev: 36.46647
# Best fitness: -94.55246 - size: (6, 20) - species 1 - id 953
# Average adjusted fitness: 0.752
# Mean genetic distance 2.113, standard deviation 0.682
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25     7    -94.6    0.659     4
#      2   24    11    -96.5    0.938     2
#      3   17    10    -95.9    0.933     9
#      4   15     9    -97.3    0.738     0
#      5   14    10    -96.1    0.954     5
#      6    7     4   -180.4    0.291     5
# Total extinctions: 0
# Generation time: 4.394 sec (4.453 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -116.27642 stdev: 33.41976
# Best fitness: -94.50817 - size: (6, 19) - species 1 - id 1147
# Average adjusted fitness: 0.712
# Mean genetic distance 2.143, standard deviation 0.648
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26     8    -94.5    0.682     0
#      2   25    10    -96.5    0.882     3
#      3   18    11    -95.9    0.910    10
#      4   16     8    -97.3    0.618     1
#      5   15    11    -96.1    0.958     6
#      6    8     3   -132.5    0.220     0
# Total extinctions: 0
# Generation time: 4.191 sec (4.443 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -115.81226 stdev: 34.41434
# Best fitness: -94.50817 - size: (6, 19) - species 1 - id 1147
# Average adjusted fitness: 0.728
# Mean genetic distance 2.118, standard deviation 0.671
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27     7    -94.5    0.654     1
#      2   26     9    -96.5    0.873     4
#      3   19    12    -95.9    0.964    11
#      4   17     9    -96.7    0.753     0
#      5   16    10    -96.1    0.821     7
#      6    9     4   -132.5    0.303     1
# Total extinctions: 0
# Generation time: 4.205 sec (4.395 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -115.10956 stdev: 32.54970
# Best fitness: -94.50817 - size: (6, 19) - species 1 - id 1147
# Average adjusted fitness: 0.724
# Mean genetic distance 2.171, standard deviation 0.664
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28     8    -94.5    0.646     2
#      2   27    10    -96.5    0.886     5
#      3   20     9    -95.9    0.916    12
#      4   18     8    -96.7    0.761     1
#      5   17    13    -96.1    0.918     8
#      6   10     3   -132.5    0.216     2
# Total extinctions: 0
# Generation time: 4.692 sec (4.415 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -112.99967 stdev: 29.85087
# Best fitness: -94.50817 - size: (6, 19) - species 1 - id 1147
# Average adjusted fitness: 0.748
# Mean genetic distance 2.155, standard deviation 0.660
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29     9    -94.5    0.833     3
#      2   28     9    -96.5    0.873     6
#      3   21    10    -95.9    0.924    13
#      4   19     9    -96.7    0.783     2
#      5   18    11    -96.1    0.815     9
#      6   11     2   -132.5    0.260     3
# Total extinctions: 0
# Generation time: 4.157 sec (4.420 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -112.32940 stdev: 29.68821
# Best fitness: -93.72194 - size: (7, 20) - species 1 - id 1300
# Average adjusted fitness: 0.771
# Mean genetic distance 2.123, standard deviation 0.665
# Population of 52 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    10    -93.7    0.846     0
#      2   29    10    -96.5    0.881     7
#      3   22    11    -95.9    0.933    14
#      4   20     8    -96.7    0.760     3
#      5   19    10    -96.1    0.795    10
#      6   12     3   -132.5    0.412     4
# Total extinctions: 0
# Generation time: 4.579 sec (4.394 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -108.12803 stdev: 24.60703
# Best fitness: -93.72194 - size: (7, 20) - species 1 - id 1300
# Average adjusted fitness: 0.804
# Mean genetic distance 2.205, standard deviation 0.655
# Population of 52 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31     9    -93.7    0.808     1
#      2   30    11    -96.3    0.967     0
#      3   23     9    -95.9    0.845    15
#      4   21     9    -96.6    0.874     0
#      5   20    10    -96.1    0.933    11
#      6   13     4   -132.5    0.400     5
# Total extinctions: 0
# Generation time: 4.380 sec (4.342 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -120.15276 stdev: 34.07218
# Best fitness: -93.72194 - size: (7, 20) - species 1 - id 1300
# Average adjusted fitness: 0.701
# Mean genetic distance 2.230, standard deviation 0.687
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     7    -93.7    0.511     2
#      2   31    11    -96.3    0.962     1
#      3   24     9    -95.9    0.760    16
#      4   22     7    -96.4    0.694     0
#      5   21    10    -96.1    0.854    12
#      6   14     5   -132.2    0.423     0
# Total extinctions: 0
# Generation time: 4.746 sec (4.411 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -114.30125 stdev: 31.91830
# Best fitness: -93.72194 - size: (7, 20) - species 1 - id 1300
# Average adjusted fitness: 0.765
# Mean genetic distance 2.249, standard deviation 0.700
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     8    -93.7    0.688     3
#      2   32    10    -96.0    0.970     0
#      3   25    10    -95.9    0.847    17
#      4   23     8    -96.4    0.720     1
#      5   22     9    -96.1    0.847    13
#      6   15     6   -132.2    0.516     1
# Total extinctions: 0
# Generation time: 4.265 sec (4.408 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -112.58394 stdev: 29.69678
# Best fitness: -93.72194 - size: (7, 20) - species 1 - id 1300
# Average adjusted fitness: 0.795
# Mean genetic distance 2.216, standard deviation 0.725
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     9    -93.7    0.979     4
#      2   33     9    -96.0    0.875     1
#      3   26     8    -95.9    0.938    18
#      4   24     7    -96.4    0.571     2
#      5   23    11    -96.1    0.877    14
#      6   16     5   -105.8    0.529     0
# Total extinctions: 0
# Generation time: 4.321 sec (4.393 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -110.95937 stdev: 29.51862
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.835
# Mean genetic distance 2.180, standard deviation 0.670
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35     8    -93.5    0.870     0
#      2   34     8    -96.0    0.798     2
#      3   27    12    -95.9    0.871    19
#      4   25     8    -96.4    0.815     3
#      5   24     7    -96.1    0.911    15
#      6   17     6   -102.0    0.746     0
# Total extinctions: 0
# Generation time: 4.322 sec (4.386 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -113.05734 stdev: 31.11457
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.795
# Mean genetic distance 2.192, standard deviation 0.680
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     7    -93.5    0.512     1
#      2   35     9    -96.0    0.968     3
#      3   28     9    -95.9    0.925    20
#      4   26     7    -96.4    0.636     4
#      5   25    10    -96.1    0.880    16
#      6   18     7    -97.4    0.849     0
# Total extinctions: 0
# Generation time: 4.271 sec (4.394 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -109.71040 stdev: 26.87947
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.836
# Mean genetic distance 2.207, standard deviation 0.717
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     8    -93.5    0.913     2
#      2   36     8    -96.0    0.867     4
#      3   29    10    -95.9    0.908    21
#      4   27     8    -96.4    0.829     5
#      5   26     9    -96.1    0.845    17
#      6   19     6    -97.4    0.652     1
# Total extinctions: 0
# Generation time: 4.222 sec (4.396 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -115.42485 stdev: 33.42007
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.801
# Mean genetic distance 2.211, standard deviation 0.713
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     7    -93.5    0.624     3
#      2   37     9    -96.0    0.868     5
#      3   30     9    -95.9    0.789    22
#      4   28     7    -96.4    0.722     6
#      5   27    10    -96.1    0.873    18
#      6   20     8    -97.4    0.932     0
# Total extinctions: 0
# Generation time: 4.591 sec (4.386 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -115.32362 stdev: 36.79669
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.837
# Mean genetic distance 2.242, standard deviation 0.714
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     8    -93.5    0.709     4
#      2   38    10    -96.0    0.976     6
#      3   31     8    -95.9    0.876    23
#      4   29     8    -96.4    0.867     7
#      5   28     9    -95.9    0.947     0
#      6   21     7    -97.4    0.646     1
# Total extinctions: 0
# Generation time: 4.468 sec (4.417 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -113.25321 stdev: 29.70301
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.793
# Mean genetic distance 2.272, standard deviation 0.676
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40     7    -93.5    0.706     5
#      2   39    11    -96.0    0.964     7
#      3   32     9    -95.9    0.785    24
#      4   30     7    -96.4    0.703     8
#      5   29     8    -95.9    0.763     1
#      6   22     8    -96.8    0.839     0
# Total extinctions: 0
# Generation time: 4.745 sec (4.433 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -113.74922 stdev: 31.43907
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.796
# Mean genetic distance 2.289, standard deviation 0.678
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     8    -93.5    0.762     6
#      2   40     9    -96.0    0.711     8
#      3   33     8    -95.9    0.759    25
#      4   31     8    -96.4    0.924     9
#      5   30     7    -95.9    0.762     2
#      6   23     9    -96.8    0.855     1
# Total extinctions: 0
# Generation time: 4.596 sec (4.455 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -110.17194 stdev: 27.56241
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.828
# Mean genetic distance 2.311, standard deviation 0.689
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     9    -93.5    0.974     7
#      2   41     8    -96.0    0.890     9
#      3   34     9    -95.9    0.853    26
#      4   32     7    -96.2    0.649     0
#      5   31     8    -95.9    0.865     3
#      6   24     8    -96.8    0.742     2
# Total extinctions: 0
# Generation time: 4.797 sec (4.460 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -105.25687 stdev: 20.64431
# Best fitness: -93.51542 - size: (7, 20) - species 1 - id 1495
# Average adjusted fitness: 0.877
# Mean genetic distance 2.282, standard deviation 0.701
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     8    -93.5    0.841     8
#      2   42     9    -96.0    0.859    10
#      3   35     8    -95.9    0.905    27
#      4   33     8    -96.2    0.826     1
#      5   32     9    -95.9    0.863     4
#      6   25     9    -95.6    0.966     0
# Total extinctions: 0
# Generation time: 3.777 sec (4.411 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -104.22416 stdev: 18.68837
# Best fitness: -92.76860 - size: (6, 19) - species 4 - id 1798
# Average adjusted fitness: 0.868
# Mean genetic distance 2.304, standard deviation 0.662
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44     7    -93.5    0.703     9
#      2   43     9    -96.0    0.845    11
#      3   36    10    -95.9    0.954    28
#      4   34     9    -92.8    0.859     0
#      5   33     6    -95.9    0.891     5
#      6   26    10    -95.6    0.954     1
# Total extinctions: 0
# Generation time: 4.821 sec (4.461 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -110.42447 stdev: 25.95628
# Best fitness: -89.26805 - size: (7, 19) - species 6 - id 1860
# Average adjusted fitness: 0.790
# Mean genetic distance 2.293, standard deviation 0.687
# Population of 49 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45     6    -93.5    0.637    10
#      2   44    10    -96.0    0.888    12
#      3   37     8    -95.9    0.847    29
#      4   35     8    -92.8    0.809     1
#      5   34     8    -95.9    0.787     6
#      6   27     9    -89.3    0.774     0
# Total extinctions: 0
# Generation time: 4.786 sec (4.507 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -107.18327 stdev: 24.11238
# Best fitness: -89.26805 - size: (7, 19) - species 6 - id 1860
# Average adjusted fitness: 0.867
# Mean genetic distance 2.266, standard deviation 0.674
# Population of 51 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46     7    -93.5    0.896    11
#      2   45     9    -96.0    0.898    13
#      3   38     9    -95.9    0.923    30
#      4   36     7    -92.8    0.642     2
#      5   35     9    -95.9    0.894     7
#      6   28    10    -89.3    0.947     1
# Total extinctions: 0
# Generation time: 4.833 sec (4.564 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -109.49918 stdev: 26.74725
# Best fitness: -89.26805 - size: (7, 19) - species 6 - id 1860
# Average adjusted fitness: 0.793
# Mean genetic distance 2.235, standard deviation 0.690
# Population of 52 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47     8    -93.5    0.762    12
#      2   46    10    -96.0    0.902    14
#      3   39    10    -95.9    0.919    31
#      4   37     8    -92.8    0.778     3
#      5   36     7    -95.9    0.542     8
#      6   29     9    -89.3    0.854     2
# Total extinctions: 0
# Generation time: 3.981 sec (4.539 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -112.23638 stdev: 29.51063
# Best fitness: -89.26805 - size: (7, 19) - species 6 - id 1860
# Average adjusted fitness: 0.799
# Mean genetic distance 2.269, standard deviation 0.694
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48     7    -93.5    0.726    13
#      2   47     9    -96.0    0.802    15
#      3   40     9    -95.9    0.914    32
#      4   38     7    -92.8    0.716     4
#      5   37     8    -95.9    0.692     9
#      6   30    10    -89.3    0.943     3
# Total extinctions: 0
# Generation time: 5.260 sec (4.606 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -119.31881 stdev: 39.17326
# Best fitness: -89.18674 - size: (7, 21) - species 6 - id 2024
# Average adjusted fitness: 0.757
# Mean genetic distance 2.253, standard deviation 0.699
# Population of 52 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49     8    -93.5    0.741    14
#      2   48    10    -96.0    0.861    16
#      3   41    10    -95.9    0.829    33
#      4   39     6    -92.8    0.590     5
#      5   38     9    -95.9    0.748    10
#      6   31     9    -89.2    0.772     0
# Total extinctions: 0
# Generation time: 4.581 sec (4.618 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: -120.01469 stdev: 41.28898
# Best fitness: -89.18674 - size: (7, 21) - species 6 - id 2024
# Average adjusted fitness: 0.799
# Mean genetic distance 2.255, standard deviation 0.671
# Population of 48 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50     7    -93.5    0.767    15
#      2   49     9    -96.0    0.886    17
#      3   42     9    -95.9    0.829    34
#      4   40     7    -92.8    0.625     6
#      5   39     8    -95.9    0.844    11
#      6   32     8    -89.2    0.845     1
# Total extinctions: 0
# Generation time: 5.250 sec (4.668 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: -123.88987 stdev: 37.12407
# Best fitness: -89.18674 - size: (7, 21) - species 6 - id 2024
# Average adjusted fitness: 0.667
# Mean genetic distance 2.273, standard deviation 0.674
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51     8    -90.6    0.687     0
#      2   50     8    -96.0    0.709    18
#      3   43    10    -95.9    0.813    35
#      4   41     8    -92.8    0.588     7
#      5   40     9    -95.9    0.672    12
#      6   33     7    -89.2    0.533     2
# Total extinctions: 0
# Generation time: 4.929 sec (4.702 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: -112.31247 stdev: 27.43385
# Best fitness: -89.18674 - size: (7, 21) - species 6 - id 2024
# Average adjusted fitness: 0.761
# Mean genetic distance 2.275, standard deviation 0.687
# Population of 48 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52     9    -90.6    0.785     1
#      2   51    10    -96.0    0.921    19
#      3   44     8    -95.9    0.815    36
#      4   42     7    -92.8    0.703     8
#      5   41     7    -95.9    0.777    13
#      6   34     6    -89.2    0.567     3
#      7    0     1       --       --     0
# Total extinctions: 0
# Generation time: 4.828 sec (4.705 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: -113.56533 stdev: 32.53279
# Best fitness: -89.18674 - size: (7, 21) - species 6 - id 2024
# Average adjusted fitness: 0.665
# Mean genetic distance 2.265, standard deviation 0.627
# Population of 51 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53     8    -90.6    0.796     2
#      2   52     9    -95.3    0.754     0
#      3   45     9    -95.9    0.859    37
#      4   43     8    -92.8    0.831     9
#      5   42     8    -95.9    0.697    14
#      6   35     7    -89.2    0.650     4
#      7    1     2   -181.9    0.068     0
# Total extinctions: 0
# Generation time: 5.145 sec (4.841 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: -120.11439 stdev: 37.61309
# Best fitness: -85.54218 - size: (7, 21) - species 6 - id 2212
# Average adjusted fitness: 0.667
# Mean genetic distance 2.253, standard deviation 0.614
# Population of 48 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54     6    -90.6    0.407     3
#      2   53     8    -95.1    0.816     0
#      3   46     7    -95.9    0.805    38
#      4   44     7    -92.8    0.704    10
#      5   43     8    -95.9    0.724    15
#      6   36     8    -85.5    0.704     0
#      7    2     4    -98.2    0.512     0
# Total extinctions: 0
# Generation time: 5.071 sec (4.866 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: -107.90094 stdev: 27.76624
# Best fitness: -85.54218 - size: (7, 21) - species 6 - id 2212
# Average adjusted fitness: 0.776
# Mean genetic distance 2.227, standard deviation 0.585
# Population of 51 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55     7    -90.6    0.869     4
#      2   54     7    -94.9    0.789     0
#      3   47     8    -95.9    0.882    39
#      4   45     6    -92.8    0.498    11
#      5   44     9    -95.9    0.882    16
#      6   37     9    -85.5    0.913     1
#      7    3     5    -98.2    0.596     1
# Total extinctions: 0
# Generation time: 4.986 sec (4.886 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: -112.71248 stdev: 30.33314
# Best fitness: -85.51226 - size: (9, 25) - species 1 - id 2278
#
# Species 3 with 8 members is stagnated: removing it
# Average adjusted fitness: 0.754
# Mean genetic distance 2.219, standard deviation 0.629
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56     9    -85.5    0.805     0
#      2   55     7    -94.3    0.622     0
#      4   46     8    -92.8    0.798    12
#      5   45     9    -95.9    0.625    17
#      6   38     9    -85.5    0.799     2
#      7    4     8    -97.4    0.875     0
# Total extinctions: 0
# Generation time: 5.209 sec (4.924 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: -120.14396 stdev: 37.66734
# Best fitness: -85.51226 - size: (9, 25) - species 1 - id 2278
# Average adjusted fitness: 0.764
# Mean genetic distance 2.167, standard deviation 0.597
# Population of 48 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57     8    -85.5    0.772     1
#      2   56     6    -94.3    0.594     1
#      4   47     9    -92.8    0.783    13
#      5   46     8    -95.9    0.767    18
#      6   39     8    -85.5    0.817     3
#      7    5     9    -97.4    0.853     1
# Total extinctions: 0
# Generation time: 5.397 sec (5.066 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: -116.25141 stdev: 34.45787
# Best fitness: -85.51226 - size: (9, 25) - species 1 - id 2278
# Average adjusted fitness: 0.760
# Mean genetic distance 2.190, standard deviation 0.626
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58     9    -85.5    0.750     2
#      2   57     7    -94.3    0.742     2
#      4   48     8    -92.8    0.683    14
#      5   47     7    -95.9    0.635    19
#      6   40     9    -85.5    0.843     4
#      7    6    10    -97.4    0.907     0
# Total extinctions: 0
# Generation time: 4.680 sec (5.008 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: -117.14223 stdev: 34.05380
# Best fitness: -85.51226 - size: (9, 25) - species 1 - id 2278
# Average adjusted fitness: 0.741
# Mean genetic distance 2.211, standard deviation 0.644
# Population of 50 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59    10    -85.5    0.849     3
#      2   58     8    -94.3    0.704     3
#      4   49     7    -92.8    0.661    15
#      5   48     8    -95.9    0.786    20
#      6   41     8    -85.5    0.613     5
#      7    7     9    -97.3    0.834     0
# Total extinctions: 0
# Generation time: 5.908 sec (5.140 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: -110.04769 stdev: 37.27743
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.402
# Mean genetic distance 2.224, standard deviation 0.614
# Population of 48 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60    10     34.6    0.486     0
#      2   59     6    -94.3    0.266     4
#      4   50     7    -92.8    0.353    16
#      5   49     8    -95.9    0.414    21
#      6   42     8    -62.0    0.430     0
#      7    8     9    -93.7    0.461     0
# Total extinctions: 0
# Generation time: 5.679 sec (5.183 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: -115.67393 stdev: 43.72964
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.366
# Mean genetic distance 2.271, standard deviation 0.633
# Population of 50 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61     9     34.6    0.365     1
#      2   60     7    -94.3    0.316     5
#      4   51     6    -92.8    0.250    17
#      5   50     9    -95.9    0.394    22
#      6   43     9    -62.0    0.449     1
#      7    9     8    -93.7    0.422     1
#      8    0     2       --       --     0
# Total extinctions: 0
# Generation time: 6.183 sec (5.309 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: -120.07912 stdev: 42.68918
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.335
# Mean genetic distance 2.282, standard deviation 0.627
# Population of 50 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62     8     34.6    0.370     2
#      2   61     6    -94.3    0.266     6
#      4   52     7    -92.8    0.330    18
#      5   51     8    -95.9    0.314    23
#      6   44     8    -62.0    0.345     2
#      7   10     9    -96.7    0.437     2
#      8    1     4    -93.7    0.284     0
# Total extinctions: 0
# Generation time: 5.825 sec (5.408 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: -114.55174 stdev: 39.22120
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.352
# Mean genetic distance 2.278, standard deviation 0.606
# Population of 50 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63     9     34.6    0.429     3
#      2   62     7    -94.3    0.322     7
#      4   53     6    -92.8    0.306    19
#      5   52     7    -95.9    0.315    24
#      6   45     7    -62.0    0.306     3
#      7   11     7    -92.7    0.434     0
#      8    2     7    -93.7    0.350     1
# Total extinctions: 0
# Generation time: 6.221 sec (5.516 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: -110.51800 stdev: 37.75540
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.335
# Mean genetic distance 2.235, standard deviation 0.644
# Population of 49 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64    10     34.6    0.435     4
#      2   63     6    -94.3    0.323     8
#      4   54     5    -92.8    0.228    20
#      5   53     6    -95.9    0.316    25
#      6   46     6    -62.0    0.327     4
#      7   12     8    -92.7    0.379     1
#      8    3     8    -82.9    0.337     0
# Total extinctions: 0
# Generation time: 6.134 sec (5.622 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: -96.98078 stdev: 38.66519
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.430
# Mean genetic distance 2.261, standard deviation 0.669
# Population of 48 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65     9     34.6    0.536     5
#      2   64     5    -94.3    0.302     9
#      4   55     6    -92.8    0.408    21
#      5   54     7    -95.9    0.427    26
#      6   47     7     22.6    0.517     0
#      7   13     7    -92.7    0.425     2
#      8    4     7    -82.9    0.393     1
# Total extinctions: 0
# Generation time: 6.011 sec (5.725 average)
# Saving checkpoint to checkpoints_ff/chk_65
#
#  ****** Running generation 66 ******
#
# Population's average fitness: -105.34572 stdev: 46.24443
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.397
# Mean genetic distance 2.280, standard deviation 0.666
# Population of 51 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66     8     34.6    0.455     6
#      2   65     6    -94.3    0.394    10
#      4   56     5    -92.8    0.326    22
#      5   55     8    -95.9    0.405    27
#      6   48     8     22.6    0.395     1
#      7   14     8    -92.7    0.410     3
#      8    5     8    -82.9    0.395     2
# Total extinctions: 0
# Generation time: 5.611 sec (5.765 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: -110.35982 stdev: 49.12591
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.396
# Mean genetic distance 2.306, standard deviation 0.667
# Population of 49 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67     7     34.6    0.422     7
#      2   66     5    -94.3    0.279    11
#      4   57     7    -92.8    0.459    23
#      5   56     7    -95.9    0.393    28
#      6   49     9     22.6    0.458     2
#      7   15     7    -92.7    0.399     4
#      8    6     7    -82.9    0.359     3
# Total extinctions: 0
# Generation time: 6.894 sec (5.915 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: -108.24421 stdev: 47.28293
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.390
# Mean genetic distance 2.261, standard deviation 0.673
# Population of 50 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68     8     34.6    0.528     8
#      2   67     6    -94.3    0.279    12
#      4   58     6    -92.8    0.372    24
#      5   57     6    -95.9    0.311    29
#      6   50     8     22.6    0.382     3
#      7   16     8    -92.7    0.408     5
#      8    7     8    -82.9    0.448     4
# Total extinctions: 0
# Generation time: 6.286 sec (6.075 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: -99.60748 stdev: 55.97158
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.397
# Mean genetic distance 2.291, standard deviation 0.662
# Population of 50 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69    10     34.6    0.657     9
#      2   68     5    -94.3    0.290    13
#      4   59     7    -92.8    0.357    25
#      5   58     5    -95.9    0.261    30
#      6   51     9     22.6    0.481     4
#      7   17     7    -92.7    0.375     6
#      8    8     7    -82.9    0.359     5
# Total extinctions: 0
# Generation time: 6.740 sec (6.158 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: -108.13701 stdev: 57.49476
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.353
# Mean genetic distance 2.304, standard deviation 0.623
# Population of 51 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70     9     34.6    0.437    10
#      2   69     6    -94.3    0.257    14
#      4   60     6    -92.8    0.231    26
#      5   59     6    -95.9    0.336    31
#      6   52    10     26.7    0.510     0
#      7   18     8    -92.7    0.383     7
#      8    9     6    -82.9    0.318     6
# Total extinctions: 0
# Generation time: 7.355 sec (6.326 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: -102.46368 stdev: 61.08535
# Best fitness: 34.62433 - size: (8, 24) - species 1 - id 2430
# Average adjusted fitness: 0.448
# Mean genetic distance 2.320, standard deviation 0.612
# Population of 52 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71     8     34.6    0.399    11
#      2   70     5    -94.3    0.351    15
#      4   61     7    -92.8    0.431    27
#      5   60     7    -95.9    0.442    32
#      6   53    11     32.4    0.701     0
#      7   19     7    -92.7    0.370     8
#      8   10     7    -82.9    0.444     7
# Total extinctions: 0
# Generation time: 6.777 sec (6.385 average)
#
#  ****** Running generation 72 ******
#
# ...
#     86   41     2     44.1    0.811    39
#     87   34     4     44.1    0.993    32
#     88   30     2   -187.6    0.035    23
#     89   29     3     38.7    0.711     7
#     90   27     2     43.3    0.806     1
#     91   22     4     42.5    0.973    19
#     92   19     2     44.1    0.635    17
#     93   12     2    -97.5    0.431    10
#     94    4     4     42.3    0.988     0
#     95    0     1       --       --     0
# Total extinctions: 0
# Generation time: 4.704 sec (4.491 average)
#
#  ****** Running generation 597 ******
#
# Population's average fitness: -3.03417 stdev: 76.94296
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
#
# Species 86 with 2 members is stagnated: removing it
# Average adjusted fitness: 0.756
# Mean genetic distance 2.380, standard deviation 0.571
# Population of 50 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  392     3     44.5    0.998   324
#     68  104     4     44.3    0.823    25
#     74   88     3     40.2    0.675     4
#     75   80     4     43.8    0.983    12
#     77   79     3     44.2    0.999    24
#     78   79     3     43.8    0.854    37
#     82   69     3     43.7    0.996    34
#     85   42     4     44.1    0.994     5
#     87   35     3     44.1    0.856    33
#     88   31     2   -187.6    0.035    24
#     89   30     2     38.7    0.739     8
#     90   28     3     43.3    0.993     2
#     91   23     3     42.5    0.921    20
#     92   20     3     44.1    0.733    18
#     93   13     2    -97.5    0.431    11
#     94    5     3     42.3    0.759     1
#     95    1     2   -190.3    0.059     0
# Total extinctions: 0
# Generation time: 4.835 sec (4.582 average)
#
#  ****** Running generation 598 ******
#
# Population's average fitness: -11.26011 stdev: 79.93363
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.744
# Mean genetic distance 2.393, standard deviation 0.553
# Population of 56 members in 18 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  393     4     44.5    0.809   325
#     68  105     3     44.3    0.756    26
#     74   89     4     40.2    0.799     5
#     75   81     3     43.8    0.845    13
#     77   80     4     44.2    0.810    25
#     78   80     6     43.8    0.809    38
#     82   70     4     43.7    0.808    35
#     85   43     1     44.2    0.857     0
#     87   36     4     44.1    0.995    34
#     88   32     2   -187.6    0.035    25
#     89   31     3     38.7    0.887     9
#     90   29     1     43.3    0.994     3
#     91   24     3     42.5    0.976    21
#     92   21     2     44.1    0.637    19
#     93   14     2    -97.5    0.431    12
#     94    6     4     43.3    0.993     0
#     95    2     2   -118.2    0.203     0
#     96    0     4       --       --     0
# Total extinctions: 0
# Generation time: 4.493 sec (4.611 average)
#
#  ****** Running generation 599 ******
#
# Population's average fitness: -21.50923 stdev: 82.54250
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.685
# Mean genetic distance 2.401, standard deviation 0.576
# Population of 52 members in 19 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  394     3     44.5    0.856   326
#     68  106     4     44.3    0.814    27
#     74   90     3     40.2    0.707     6
#     75   82     2     43.8    0.807    14
#     77   81     3     44.2    0.726    26
#     78   81     5     44.2    0.994     0
#     82   71     3     43.7    0.865    36
#     85   44     3     44.1    0.998     1
#     87   37     3     44.1    0.717    35
#     88   33     2   -187.6    0.035    26
#     89   32     2     38.7    0.736    10
#     90   30     3    -96.2    0.436     4
#     91   25     2     42.5    0.672    22
#     92   22     3     44.1    0.733    20
#     93   15     2    -97.5    0.431    13
#     94    7     3     43.3    0.986     1
#     95    3     2   -118.2    0.203     1
#     96    1     3     43.3    0.619     0
#     97    0     1       --       --     0
# Total extinctions: 0
# Generation time: 4.818 sec (4.648 average)
#
#  ****** Running generation 600 ******
#
# Population's average fitness: -24.03776 stdev: 83.12019
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.690
# Mean genetic distance 2.398, standard deviation 0.580
# Population of 54 members in 19 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  395     4     44.5    0.822   327
#     68  107     3     44.3    0.856    28
#     74   91     4     40.2    0.981     7
#     75   83     1     43.8    0.993    15
#     77   82     4     44.2    0.810    27
#     78   82     4     44.2    0.979     1
#     82   72     4     43.7    0.809    37
#     85   45     2     44.1    0.621     2
#     87   38     2     44.1    0.687    36
#     88   34     2   -187.6    0.035    27
#     89   33     3     38.7    0.887    11
#     90   31     2    -96.0    0.433     5
#     91   26     3     42.5    0.989    23
#     92   23     2     44.1    0.643    21
#     93   16     2    -97.5    0.431    14
#     94    8     2     43.3    0.682     2
#     95    4     2   -118.2    0.203     2
#     96    2     4     43.3    0.810     1
#     97    1     4    -96.8    0.434     0
# Total extinctions: 0
# Generation time: 4.659 sec (4.665 average)
#
#  ****** Running generation 601 ******
#
# Population's average fitness: -20.87594 stdev: 85.02850
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.719
# Mean genetic distance 2.388, standard deviation 0.572
# Population of 55 members in 19 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  396     3     44.5    0.621   328
#     68  108     4     44.3    0.823    29
#     74   92     3     40.2    0.974     8
#     75   84     2     41.5    0.988    16
#     77   83     3     44.2    0.998    28
#     78   83     2     44.2    0.760     2
#     82   73     3     43.7    0.855    38
#     85   46     4     44.1    0.715     3
#     87   39     3     44.1    0.998    37
#     88   35     2   -187.6    0.035    28
#     89   34     4     38.7    0.911    12
#     90   32     2    -96.0    0.437     6
#     91   27     3     42.5    0.984    24
#     92   24     3     44.1    0.733    22
#     93   17     2    -97.5    0.431    15
#     94    9     3     43.3    0.993     3
#     95    5     2   -118.2    0.203     3
#     96    3     3     43.3    0.621     2
#     97    2     4     43.8    0.576     0
# Total extinctions: 0
# Generation time: 4.902 sec (4.703 average)
#
#  ****** Running generation 602 ******
#
# Population's average fitness: -23.94285 stdev: 85.28200
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.715
# Mean genetic distance 2.361, standard deviation 0.566
# Population of 55 members in 19 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  397     4     44.5    0.823   329
#     68  109     3     44.3    0.621    30
#     74   93     2     40.2    0.801     9
#     75   85     3     41.5    0.975    17
#     77   84     4     44.2    0.998    29
#     78   84     3     44.2    0.998     3
#     82   74     4     43.7    0.992    39
#     85   47     3     44.1    0.481     4
#     87   40     4     44.1    0.991    38
#     88   36     2   -187.6    0.035    29
#     89   35     3     38.7    0.835    13
#     90   33     3     42.5    0.714     7
#     91   28     4     42.5    0.989    25
#     92   25     2     44.1    0.633    23
#     93   18     2    -97.5    0.431    16
#     94   10     2     43.3    0.683     4
#     95    6     2   -118.2    0.203     4
#     96    4     2     43.3    0.807     3
#     97    3     3     43.8    0.577     1
# Total extinctions: 0
# Generation time: 4.966 sec (4.733 average)
#
#  ****** Running generation 603 ******
#
# Population's average fitness: -24.24309 stdev: 82.96310
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
#
# Species 82 with 4 members is stagnated: removing it
# Average adjusted fitness: 0.704
# Mean genetic distance 2.387, standard deviation 0.552
# Population of 52 members in 18 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  398     3     44.5    0.871   330
#     68  110     2     44.3    0.685    31
#     74   94     3     40.2    0.983    10
#     75   86     4     41.5    0.794    18
#     77   85     3     44.2    0.715    30
#     78   85     3     44.2    0.809     4
#     85   48     2     44.1    0.621     5
#     87   41     3     44.1    0.856    39
#     88   37     2   -187.6    0.035    30
#     89   36     3     38.7    0.795    14
#     90   34     4     42.5    0.495     8
#     91   29     2     42.6    0.851     0
#     92   26     3     44.1    0.733    24
#     93   19     2    -97.5    0.431    17
#     94   11     4     43.3    0.993     5
#     95    7     2   -118.2    0.203     5
#     96    5     3     43.3    0.995     4
#     97    4     4     43.8    0.811     2
# Total extinctions: 0
# Generation time: 4.799 sec (4.762 average)
#
#  ****** Running generation 604 ******
#
# Population's average fitness: -16.68963 stdev: 80.20581
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
#
# Species 87 with 3 members is stagnated: removing it
# Average adjusted fitness: 0.720
# Mean genetic distance 2.404, standard deviation 0.575
# Population of 53 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  399     4     44.5    0.822   331
#     68  111     3     44.3    0.999    32
#     74   95     4     42.5    0.986     0
#     75   87     3     41.5    0.819    19
#     77   86     2     44.2    0.687    31
#     78   86     4     44.2    0.993     5
#     85   49     3     44.1    0.715     6
#     88   38     3   -187.6    0.035    31
#     89   37     4     38.7    0.793    15
#     90   35     3     42.5    0.573     9
#     91   30     3     42.6    0.992     1
#     92   27     3     44.1    0.819    25
#     93   20     2    -97.5    0.431    18
#     94   12     3     43.3    0.844     6
#     95    8     2   -118.2    0.203     6
#     96    6     4     43.3    0.807     5
#     97    5     3     43.8    0.715     3
# Total extinctions: 0
# Generation time: 4.566 sec (4.730 average)
#
#  ****** Running generation 605 ******
#
# Population's average fitness: -6.73076 stdev: 80.73240
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.767
# Mean genetic distance 2.361, standard deviation 0.554
# Population of 50 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  400     3     44.5    0.855   332
#     68  112     2     44.3    0.694    33
#     74   96     3     43.8    0.983     0
#     75   88     4     41.5    0.796    20
#     77   87     3     44.2    0.999    32
#     78   87     3     44.2    0.993     6
#     85   50     2     44.1    0.621     7
#     88   39     2   -187.6    0.044    32
#     89   38     3     38.7    0.832    16
#     90   36     4     42.5    0.620    10
#     91   31     2     43.3    0.993     0
#     92   28     4     44.1    0.995    26
#     93   21     2    -97.5    0.431    19
#     94   13     4     43.3    0.992     7
#     95    9     2   -118.2    0.203     7
#     96    7     3     43.3    0.991     6
#     97    6     4     43.8    0.992     4
# Total extinctions: 0
# Generation time: 4.962 sec (4.771 average)
#
#  ****** Running generation 606 ******
#
# Population's average fitness: -23.62314 stdev: 84.67832
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.723
# Mean genetic distance 2.352, standard deviation 0.569
# Population of 52 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  401     4     44.5    0.818   333
#     68  113     3     44.3    0.999    34
#     74   97     4     43.8    0.815     1
#     75   89     3     41.5    0.717    21
#     77   88     4     44.2    0.998    33
#     78   88     5     44.2    0.987     7
#     85   51     2     44.1    0.727     8
#     88   40     2   -187.6    0.104    33
#     89   39     4     38.7    0.970    17
#     90   37     3     42.6    0.589    11
#     91   32     3     43.3    0.994     1
#     92   29     3     44.1    0.735    27
#     93   22     2    -97.5    0.453    20
#     94   14     3     43.3    0.636     8
#     95   10     2   -118.2    0.235     8
#     96    8     2     43.3    0.663     7
#     97    7     3     43.8    0.851     5
# Total extinctions: 0
# Generation time: 4.404 sec (4.741 average)
#
#  ****** Running generation 607 ******
#
# Population's average fitness: -14.86207 stdev: 80.27027
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.711
# Mean genetic distance 2.330, standard deviation 0.567
# Population of 54 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  402     3     44.5    0.746   334
#     68  114     4     44.3    0.798    35
#     74   98     3     43.8    0.659     2
#     75   90     4     41.5    0.905    22
#     77   89     3     44.2    0.847    34
#     78   89     3     44.2    0.878     8
#     85   52     4     44.1    0.698     9
#     88   41     2   -187.6    0.008    34
#     89   40     3     38.7    0.827    18
#     90   38     2     42.6    0.598    12
#     91   33     4     43.3    0.797     2
#     92   30     4     44.1    0.797    28
#     93   23     2    -97.5    0.395    21
#     94   15     4     43.6    0.994     0
#     95   11     2   -118.2    0.154     9
#     96    9     3     43.3    0.995     8
#     97    8     4     43.9    0.997     0
# Total extinctions: 0
# Generation time: 4.604 sec (4.717 average)
#
#  ****** Running generation 608 ******
#
# Population's average fitness: -30.91635 stdev: 89.80267
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.647
# Mean genetic distance 2.321, standard deviation 0.572
# Population of 55 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  403     4     44.5    0.670   335
#     68  115     3     44.3    0.500    36
#     74   99     4     43.8    0.811     3
#     75   91     3     41.5    0.686    23
#     77   90     4     44.2    0.800    35
#     78   90     4     44.2    0.793     9
#     85   53     3     44.1    0.845    10
#     88   42     2   -187.6    0.015    35
#     89   41     4     38.7    0.784    19
#     90   39     2     42.6    0.699    13
#     91   34     5     43.8    0.983     0
#     92   31     3     44.1    0.603    29
#     93   24     2    -97.5    0.399    22
#     94   16     3     43.6    0.600     1
#     95   12     2   -118.2    0.159    10
#     96   10     4     43.3    0.798     9
#     97    9     3     43.9    0.849     1
# Total extinctions: 0
# Generation time: 4.802 sec (4.748 average)
#
#  ****** Running generation 609 ******
#
# Population's average fitness: -8.61303 stdev: 80.24726
# Best fitness: 44.46321 - size: (4, 7) - species 20 - id 9383
# Average adjusted fitness: 0.719
# Mean genetic distance 2.314, standard deviation 0.567
# Population of 54 members in 17 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     20  404     3     44.5    0.749   336
#     68  116     4     44.3    0.998    37
#     74  100     3     43.8    0.844     4
#     75   92     4     41.5    0.781    24
#     77   91     5     44.2    0.996    36
#     78   91     3     44.2    0.850    10
#     85   54     2     44.1    0.666    11
#     88   43     2   -187.6    0.008    36
#     89   42     3     39.1    0.972     0
#     90   40     2    -94.5    0.405    14
#     91   35     4     43.8    0.885     1
#     92   32     4     44.1    0.829    30
#     93   25     2    -97.5    0.395    23
#     94   17     4     43.6    0.996     2
#     95   13     2   -118.2    0.154    11
#     96   11     3     43.3    0.696    10
#     97   10     4     43.9    0.995     2
# Total extinctions: 0
# Generation time: 5.156 sec (4.782 average)
#
#  ****** Running generation 610 ******
